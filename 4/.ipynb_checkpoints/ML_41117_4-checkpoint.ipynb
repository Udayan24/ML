# %% [markdown]
# <h1>ML - Assignment 4 - 41117 (P1)</h1>

# %% [markdown]
# <b>Implement Gradient Descent Algorithm to find local minima of a function.</b><br>Ex: Find local minima of y=(x+3)^2 starting from the point x=2

# %% [markdown]
# It is an optimisation algorithm used to find max/min of a function. We optimise parameters to find local max/min.

# %% [markdown]
# Import dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# y = (x+3)^2<br>
# After differentiating, y = 2(x+3) = slope

# %%
slope = lambda x: (x+3)*2

# %%
print(df(2))
# Out:
# 10

# %% [markdown]
# Initialize terms

# %%
x = 2                  
learning_rate = 0.01   
precision = 0.000001
max_it = 500 

prev_step_size = 1 
it = 0

# %% [markdown]
# Gradient Descent Algorithm

# %%
x_list = []

while prev_step_size > precision and it < max_it:
    x_list.append(x)
    prev_x = x 
    
    # New Value = Old Value - Step size 
    # where Step size = learning rate * Slope of function
    x = x - (learning_rate * slope(prev_x)) # Iteration 1: x = 2 - (0.01*10) = 1.9
    
    # Calculate step size
    prev_step_size = abs(x - prev_x)     # Iteration 1: prev_step_size = abs(1.9-2) = 0.1
    
    # Iteration count
    it = it+1 
    
    # Print iterations
    print("Iteration", it, "\nX value is", x)
# Out:
# Iteration 1
# X value is 1.9
# Iteration 2
# X value is 1.8019999999999998
# Iteration 3
# X value is 1.70596
# Iteration 4
# X value is 1.6118408
# Iteration 5
# X value is 1.519603984
# Iteration 6
# X value is 1.42921190432
# Iteration 7
# X value is 1.3406276662336
# Iteration 8
# X value is 1.253815112908928
# Iteration 9
# X value is 1.1687388106507495
# Iteration 10
# X value is 1.0853640344377344
# Iteration 11
# X value is 1.0036567537489798
# Iteration 12
# X value is 0.9235836186740002
# Iteration 13
# X value is 0.8451119463005202
# Iteration 14
# X value is 0.7682097073745098
# Iteration 15
# X value is 0.6928455132270196
# Iteration 16
# X value is 0.6189886029624792
# Iteration 17
# X value is 0.5466088309032295
# Iteration 18
# X value is 0.4756766542851649
# Iteration 19
# X value is 0.40616312119946163
# Iteration 20
# X value is 0.3380398587754724
# Iteration 21
# X value is 0.27127906159996296
# Iteration 22
# X value is 0.2058534803679637
# Iteration 23
# ...

# %% [markdown]
# Print Local Minimum

# %%
print("\nLocal minimum: ", x)
# Out:
# Local minimum:  -2.9997948800742726

# %% [markdown]
# Plot the graph

# %%
x_g = np.linspace(-5, -1) # Return evenly spaced numbers
y_g = []

for i in x_g:
  y_g.append((i+3)**2)

plt.plot(x_g,y_g)
